# %%
import os
import json
import pandas as pd
from ast import literal_eval
from urllib.request import urlretrieve

from pathlib import Path
from grobid.models.form import Form, File
from grobid.models.response import Response
from grobid.client import Client, GrobidClientError
from grobid.tei import Parser

# %% [markdown]
# # Test Grobid

# %%
def grobid_parse(pdf_path):
    pdf_file = Path(pdf_path)
    with open(pdf_file, "rb") as file:
        form = Form(
            file=File(
                payload=file.read(),
                file_name=pdf_file.name,
                mime_type="application/pdf",
            )
        )
        c = Client(base_url="https://kermitt2-grobid.hf.space", form=form)
        try:
            xml_content = c.sync_request().content  # TEI XML file in bytes
            parser = Parser(xml_content)
            return parser.parse()
        except GrobidClientError as e:
            print(e)

pdf_path = '../data/raw/pdfs/conf_ircdl_GemelliVM23.pdf'
article = grobid_parse(pdf_path)

# %%
article.bibliography.authors
# Out:
# [Author(person_name=PersonName(surname='Gemelli', first_name='Andrea'), affiliations=[Affiliation(department="Dipartimento di Ingegneria dell'Informazione (DINFO", institution='Università degli studi di Firenze', laboratory=None)], email='andrea.gemelli@unifi.it'),
#  Author(person_name=PersonName(surname='Vivoli', first_name='Emanuele'), affiliations=[Affiliation(department="Dipartimento di Ingegneria dell'Informazione (DINFO", institution='Università degli studi di Firenze', laboratory=None)], email='emanuele.vivoli@unifi.it'),
#  Author(person_name=PersonName(surname='Marinai', first_name='Simone'), affiliations=[Affiliation(department="Dipartimento di Ingegneria dell'Informazione (DINFO", institution='Università degli studi di Firenze', laboratory=None)], email='simone.marinai@unifi.it')]

# %%
for a in article.bibliography.authors:
    fullname = a.person_name.first_name + ' ' +  a.person_name.surname
    orgs = [org.institution for org in a.affiliations]
    print(fullname, orgs)
# Out:
# Andrea Gemelli ['Università degli studi di Firenze']
# Emanuele Vivoli ['Università degli studi di Firenze']
# Simone Marinai ['Università degli studi di Firenze']

# %%
article.to_json()
# Out:
# '{"bibliography":{"title":"CTE: A Dataset for Contextualized Table Extraction","authors":[{"person_name":{"surname":"Gemelli","first_name":"Andrea"},"affiliations":[{"department":"Dipartimento di Ingegneria dell\'Informazione (DINFO","institution":"Università degli studi di Firenze","laboratory":null}],"email":"andrea.gemelli@unifi.it"},{"person_name":{"surname":"Vivoli","first_name":"Emanuele"},"affiliations":[{"department":"Dipartimento di Ingegneria dell\'Informazione (DINFO","institution":"Università degli studi di Firenze","laboratory":null}],"email":"emanuele.vivoli@unifi.it"},{"person_name":{"surname":"Marinai","first_name":"Simone"},"affiliations":[{"department":"Dipartimento di Ingegneria dell\'Informazione (DINFO","institution":"Università degli studi di Firenze","laboratory":null}],"email":"simone.marinai@unifi.it"}],"date":null,"ids":null,"target":null,"publisher":null,"journal":null,"series":null,"scope":null},"keywords":["Scientific paper analysis","Dataset","Benchmark","Document layout analysis","Table extraction"],"citations":{"b0":{"title":"Learning algorithms for document layout analysis","authors":[{"person_name":{"surname":"Marinai","first_name":"S"},"affiliations":[],"email":null}],"date":{"year":"2013","month":null,"day":null},"ids":{"DOI":"10.1016/B978-0-444-53859-8.00016-3","arXiv":null},"target":"https://doi.org/10.1016/B978-0-444-53859-8.00016-3","publisher":"Elsevier","journal":null,"series":"Handbook of Statistics","scope":{"volume":31,"pages":{"from_page":400,"to_page":419}}},"b1":{"title":"Current status and performance analysis of table recognition in document images with deep neural networks","authors":[{"person_name":{"surname":"Hashmi","first_name":"K"},"affiliations":[],"email":null},{"person_name":{"surname":"Liwicki","first_name":"M"},"affiliations":[],"email":null},{"person_name":{"surname":"Stricker","first_name":"D"},"affiliations":[],"email":null},{"person_name":{"surname":"Afzal","first_name":"M"},"affiliations":[],"email":null},{"person_name":{"surname":"Afzal","first_name":"M"},"affiliations":[],"email":null}],"date":{"year":"2021","month":null,"day":null},"ids":{"DOI":"10.1109/ACCESS.2021.3087865","arXiv":null},"target":"https://doi.org/10.1109/ACCESS.2021.3087865","publisher":null,"journal":"IEEE Access","series":null,"scope":{"volume":9,"pages":{"from_page":87663,"to_page":87685}}},"b2":{"title":"Axcell: Automatic extraction of results from machine learning papers","authors":[{"person_name":{"surname":"Kardas","first_name":"M"},"affiliations":[],"email":null},{"person_name":{"surname":"Czapla","first_name":"P"},"affiliations":[],"email":null},{"person_name":{"surname":"Stenetorp","first_name":"P"},"affiliations":[],"email":null},{"person_name":{"surname":"Ruder","first_name":"S"},"affiliations":[],"email":null},{"person_name":{"surname":"Riedel","first_name":"S"},"affiliations":[],"email":null},{"person_name":{"surname":"Taylor","first_name":"R"},"affiliations":[],"email":null},{"person_name":{"surname":"Stojnic","first_name":"R"},"affiliations":[],"email":null}],"date":{"year":"2020","month":null,"day":null},"ids":{"DOI":"10.18653/v1/2020.emnlp-main.692","arXiv":null},"target":"https://doi.org/10.18653/v1/2020.emnlp-main.692.doi:10.18653/v1/2020.emnlp-main.692","publisher":"Association for Computational Linguistics","journal":null,"series":null,"scope":{"volume":null,"pages":{"from_page":8580,"to_page":8594}}},"b3":{"title":"Publaynet: Largest dataset ever for document layout analysis","authors":[{"person_name":{"surname":"Zhong","first_name":"X"},"affiliations":[],"email":null},{"person_name":{"surname":"Tang","first_name":"J"},"affiliations":[],"email":null},{"person_name":{"surname":"Jimeno-Yepes","first_name":"A"},"affiliations":[],"email":null}],"date":{"year":"2019","month":null,"day":null},"ids":{"DOI":"10.1109/ICDAR.2019.00166","arXiv":null},"target":"https://doi.org/10.1109/ICDAR.2019.00166.doi:10.1109/ICDAR.2019.00166","publisher":"IEEE","journal":null,"series":null,"sc ...

# %%
json.loads(article.to_json())
# Out:
# {'bibliography': {'title': 'Will Open Science Change Authorship for Good? Towards a Quantitative Analysis',
#   'authors': [{'person_name': {'surname': 'Mannocci', 'first_name': 'Andrea'},
#     'affiliations': [{'department': 'Institute of Information Science and Technologies',
#       'institution': 'CNR-ISTI -National Research Council "Alessandro Faedo"',
#       'laboratory': None}],
#     'email': 'andrea.mannocci@isti.cnr.it'},
#    {'person_name': {'surname': 'Irrera', 'first_name': 'Ornella'},
#     'affiliations': [{'department': 'Institute of Information Science and Technologies',
#       'institution': 'CNR-ISTI -National Research Council "Alessandro Faedo"',
#       'laboratory': None},
#      {'department': 'Department of Information Engineering',
#       'institution': 'University of Padova',
#       'laboratory': None}],
#     'email': 'ornella.irrera@studenti.unipd.it'},
#    {'person_name': {'surname': 'Manghi', 'first_name': 'Paolo'},
#     'affiliations': [{'department': 'Institute of Information Science and Technologies',
#       'institution': 'CNR-ISTI -National Research Council "Alessandro Faedo"',
#       'laboratory': None},
#      {'department': None, 'institution': 'OpenAIRE AMKE', 'laboratory': None}],
#     'email': 'paolo.manghi@isti.cnr.it'}],
#   'date': None,
#   'ids': None,
#   'target': None,
#   'publisher': None,
#   'journal': None,
#   'series': None,
#   'scope': None},
#  'keywords': ['Data citation',
#   'Open science',
#   'Scholarly communication',
#   'Authorship',
#   'Research literature',
#   'Research data'],
#  'citations': {'b0': {'title': 'Hyperauthorship: A postmodern perversion or evidence of a structural shift in scholarly communication practices?',
#    'authors': [{'person_name': {'surname': 'Cronin', 'first_name': 'B'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2001', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1002/asi.1097', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Journal of the American Society for Information Science and Technology',
#    'series': None,
#    'scope': {'volume': 52, 'pages': {'from_page': 558, 'to_page': 569}}},
#   'b1': {'title': 'The write position: A survey of perceived contributions to papers based on byline position and number of authors',
#    'authors': [{'person_name': {'surname': 'Wren', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Kozak', 'first_name': 'K'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Johnson', 'first_name': 'K'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Deakyne', 'first_name': 'S'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Schilling', 'first_name': 'L'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Dellavalle', 'first_name': 'R'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2007', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'EMBO reports',
#    'series': None,
#    'scope': {'volume': 8, 'pages': {'from_page': 988, 'to_page': 991}}},
#   'b2': {'title': 'Publish together or perish: the increasing number of authors per article in academic journals is the consequence of a changing scientific culture. some researchers define authorship quite loosely',
#    'authors': [{'person_name': {'surname': 'Baethge', 'first_name': 'C'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2008', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'Deutsches Arzteblatt International',
#    'series': None,
#    'scope': {'volume': 105, 'pages': {'from_page': 380, 'to_page': 380}}},
#   'b3': {'title': 'Evolution in the number of authors of computer science publications',
#    'authors': [{'person_name': {'surname': 'Fernandes', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Monteiro', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2017', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'Scientometrics',
#    'series': None,
#    'scope': {'volume': 110, 'pages': {'from_page': 529, 'to_page': 539}}},
#   'b4': {'title': 'What is in a name? Credit assignment practices in different disciplines',
#    'authors': [{'person_name': {'surname': 'Frandsen', 'first_name': 'T'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Nicolaisen', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2010', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1016/j.joi.2010.06.010', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Journal of Informetrics',
#    'series': None,
#    'scope': {'volume': 4, 'pages': {'from_page': 608, 'to_page': 617}}},
#   'b5': {'title': '',
#    'authors': [{'person_name': {'surname': 'Aad', 'first_name': 'G'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2012', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'PHYSICAL REVIEW D Phys Rev D',
#    'series': None,
#    'scope': {'volume': 85, 'pages': {'from_page': 12003, 'to_page': 12003}}},
#   'b6': {'title': 'Beyond authorship: Attribution, contribution, collaboration, and credit',
#    'authors': [{'person_name': {'surname': 'Brand', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Allen', 'first_name': 'L'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Altman', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Hlava', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Scott', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2015', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1087/20150211', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Learned Publishing',
#    'series': None,
#    'scope': {'volume': 28, 'pages': None}},
#   'b7': {'title': "Is authorship sufficient for today's collaborative research? a call for contributor roles",
#    'authors': [{'person_name': {'surname': 'Vasilevsky', 'first_name': 'N'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Hosseini', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Teplitzky', 'first_name': 'S'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Ilik', 'first_name': 'V'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Mohammadi', 'first_name': 'E'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Schneider', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Kern', 'first_name': 'B'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Colomb', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Edmunds', 'first_name': 'S'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Gutzman', 'first_name': 'K'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Himmelstein', 'first_name': 'D'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'White', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Smith', 'first_name': 'B'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': "O'keefe", 'first_name': 'L'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Haendel', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Holmes', 'first_name': 'K'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2021', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1080/08989621.2020.1779591', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Accountability in Research',
#    'series': None,
#    'scope': {'volume': 28, 'pages': {'from_page': 23, 'to_page': 43}}},
#   'b8': {'title': "Authorship: Who's on first?",
#    'authors': [{'person_name': {'surname': 'Dance', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2012', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1038/nj7417-591a', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Nature',
#    'series': None,
#    'scope': {'volume': 489, 'pages': {'from_page': 591, 'to_page': 593}}},
#   'b9': {'title': 'The Anatomy of a Data Citation: Discovery, Reuse, and Credit',
#    'authors': [{'person_name': {'surname': 'Mooney', 'first_name': 'H'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Newton', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2012', 'month': None, 'day': None},
#    'ids': {'DOI': '10.7710/2162-3309.1035', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Journal of Librarianship and Scholarly Communication',
#    'series': None,
#    'scope': {'volume': 1, 'pages': {'from_page': 1035, 'to_page': 1035}}},
#   'b10': {'title': 'Theory and Practice of Data Citation',
#    'authors': [{'person_name': {'surname': 'Silvello', 'first_name': 'G'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2018', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1002/asi.23917', 'arXiv': 'arXiv:1706.07976'},
#    'target': None,
#    'publisher': None,
#    'journal': 'Journal of the Association for Information Science and Technology',
#    'series': None,
#    'scope': {'volume': 69, 'pages': {'from_page': 6, 'to_page': 20}}},
#   'b11': {'title': 'Data Authorship as an Incentive to Data Sharing',
#    'authors': [{'person_name': {'surname': 'Bierer', 'first_name': 'B'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Crosas', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Pierce', 'first_name': 'H'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2017', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1056/NEJMsb1616595', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'New England Journal of Medicine',
#    'series': None,
#    'scope': {'volume': 376, 'pages': {'from_page': 1684, 'to_page': 1687}}},
#   'b12': {'title': 'The order in the lists of authors in multi-author papers revisited',
#    'authors': [{'person_name': {'surname': 'Kosmulski', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2012', 'month': None, 'day': None},
#    'ids': {'DOI': '10.1016/j.joi.2012.06.006', 'arXiv': None},
#    'target': None,
#    'publisher': None,
#    'journal': 'Journal of Informetrics',
#    'series': None,
#    'scope': {'volume': 6, 'pages': {'from_page': 639, 'to_page': 644}}},
#   'b13': {'title': 'Open Science Graphs Must Interoperate!',
#    'authors': [{'person_name': {'surname': 'Aryani', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Fenner', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Manghi', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Mannocci', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Stocker', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2020', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': 'Springer',
#    'journal': None,
#    'series': None,
#    'scope': {'volume': None, 'pages': {'from_page': 195, 'to_page': 206}}},
#   'b14': {'title': 'Openaire research graph dump',
#    'authors': [{'person_name': {'surname': 'Manghi', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Atzori', 'first_name': 'C'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bardi', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Baglioni', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Schirrwagen', 'first_name': 'J'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Dimitropoulos', 'first_name': 'H'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'La', 'first_name': 'S'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bruzzo', 'first_name': 'I'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Foufoulas', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Löhden', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bäcker', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Mannocci', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Horst', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Jacewicz', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Czerniak', 'first_name': 'K'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Kiatropoulou', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Kokogiannaki', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bonis', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Artini', 'first_name': 'E'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Ottonello', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Lempesis', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Ioannidis', 'first_name': 'N'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Manola', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Principe', 'first_name': None},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2020', 'month': None, 'day': None},
#    'ids': {'DOI': '10.5281/zenodo.4279381', 'arXiv': None},
#    'target': 'https://doi.org/10.5281/zenodo.4279381.doi:10.5281/zenodo.4279381',
#    'publisher': None,
#    'journal': None,
#    'series': None,
#    'scope': None},
#   'b15': {'title': 'De-duplication of aggregation authority files',
#    'authors': [{'person_name': {'surname': 'Manghi', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Mikulicic', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Atzori', 'first_name': 'C'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2012', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'International Journal of Metadata, Semantics and Ontologies',
#    'series': None,
#    'scope': {'volume': 7, 'pages': {'from_page': 114, 'to_page': 130}}},
#   'b16': {'title': 'Entity deduplication in big data graphs for scholarly communication',
#    'authors': [{'person_name': {'surname': 'Manghi', 'first_name': 'P'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Atzori', 'first_name': 'C'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bonis', 'first_name': 'M'},
#      'affiliations': [],
#      'email': None},
#     {'person_name': {'surname': 'Bardi', 'first_name': 'A'},
#      'affiliations': [],
#      'email': None}],
#    'date': {'year': '2020', 'month': None, 'day': None},
#    'ids': None,
#    'target': None,
#    'publisher': None,
#    'journal': 'Data Technologies and Applications',
#    'series': None,
#    'scope': None}},
#  'sections': [{'title': 'Introduction',
#    'paragraphs': [{'text': 'While, in early science, most of the papers were authored by a handful of scientists, modern science is characterised by more extensive collaborations, and the average number of authors per article has increased across many disciplines [1,2,3,4,5]. Indeed, in some fields of science (e.g., High Energy Physics), it is not infrequent to encounter hundreds or thousands of authors co-participating in the same piece of research [6]. Such intricate collaboration patterns make it particularly hard to establish a correct relationship between contributor and scientific contribution, and hence get an accurate and fair reward during research evaluation [7,8]. Thus, as widely known, scientific authorship tends to be a rather hot-button topic in academia as roughly one-fifth of academic disputes among authors stems from this [9].',
#      'refs': [{'start': 236, 'end': 239, 'marker': 'bibr', 'target': '#b0'},
#       {'start': 239, 'end': 241, 'marker': 'bibr', 'target': '#b1'},
#       {'start': 241, 'end': 243, 'marker': 'bibr', 'target': '#b2'},
#       {'start': 243, 'end': 245, 'marker': 'bibr', 'target': '#b3'},
#       {'start': 245, 'end': 247, 'marker': 'bibr', 'target': '#b4'},
#       {'start': 426, 'end': 429, 'marker': 'bibr', 'target': '#b5'},
#       {'start': 649, 'end': 652, 'marker': 'bibr', 'target': '#b6'},
#       {'start': 652, 'end': 654, 'marker': 'bibr', 'target': '#b7'},
#       {'start': 823, 'end': 826, 'marker': 'bibr', 'target': '#b8'}]},
#     {'text': 'Open Science, however, has the potential to disrupt such traditional mechanisms by injecting into the "academic market" new kinds of "currency" for credit attribution, merit and impact assessment [10,11]. To this end, the new practices of research data (and software) deposition and citation could be perceived as an opportunity to diversify scientific attribution and eventually give credit -right where it feels most appropriate -to the different contributors involved in the diverse phases of the lifecycle within the same research endeavour [7,12].',
#      'refs': [{'start': 196, 'end': 200, 'marker': 'bibr', 'target': '#b9'},
#       {'start': 200, 'end': 203, 'marker': 'bibr', 'target': '#b10'},
#       {'start': 545, 'end': 548, 'marker': 'bibr', 'target': '#b6'},
#       {'start': 548, 'end': 551, 'marker': 'bibr', 'target': '#b11'}]},
#     {'text': "In this extended abstract, we outline the perspective of using modern Open Science Graphs (OSGs) to analyse whether this is the case or not and understand if the opportunity has been seized already. Offering extensive metadata descriptions of both literature and research data records and the semantic relations among them, OSGs can be conducive to computational analysis of this phenomenon and thus study the emergence of significant patterns. In particular, it will be interesting to analyse whether and how the authors' number, composition, and order varies when moving from literature to research data and software.",
#      'refs': []},
#     {'text': 'It would be, for example, interesting to discover that a significantly larger amount of people is involved in the development of software and the construction of datasets rather than in the editing of the related publications. This would confirm that the current reward mechanisms are obsolete and that there is a consistent, submerged workforce contributing to research that risks being underrepresented and under-evaluated if the current practices do not change for good.',
#      'refs': []},
#     {'text': 'Furthermore, modifications in the composition (by shuffle or by omission) of the authors participating in a publication as opposed to the ones contributing to related research data (or software) could instead reveal other interesting aspects worth investigating. While, on the one hand, such changes in the two author lists could be contingent [13], on the other, it could be interesting to relate them to the seniority of authors in order to detect patterns revealing a possible agency behind such a choice. For example, data could suggest that senior staff members are less involved or, by any mean less interested, in participating, or getting rewarded, for data production and software development, thus confirming a bias towards the status quo of research assessment.',
#      'refs': [{'start': 344,
#        'end': 348,
#        'marker': 'bibr',
#        'target': '#b12'}]}]},
#   {'title': 'Data and methods',
#    'paragraphs': [{'text': 'In this section, we describe the dataset we intend to use to power our study, and we provide an overview of the methodology we intend to adhere to as well as the major caveats and challenges.',
#      'refs': []}]},
#   {'title': 'Data',
#    'paragraphs': [{'text': 'The study here suggested is possible thanks to the ever-increasing amount of metadata about research products of the last decade. In particular, Open Science Graphs (OSGs) can be a goldmine to this extent. OSGs are Scientific Knowledge Graphs whose intent is to improve the overall FAIRness of science by enabling open access to graph representations of metadata about people, artefacts, institutions involved in the research lifecycle, as well as the relations between such entities, to support stakeholder needs, such as discovery, reuse, reproducibility, statistics, trends, monitoring, validation, and impact assessment. The represented information may span entities such as research artefacts (e.g., publications, data, software, samples, instruments) and items of their content (e.g., statistical hypothesis tests reported in publications), research organisations, researchers, services, projects, and funders. OSGs include relationships between such entities and sometimes formalised (semantic) concepts characterising them, such as machine-readable concept descriptions for advanced discoverability, interoperability, and reuse [14].',
#      'refs': [{'start': 1136,
#        'end': 1140,
#        'marker': 'bibr',
#        'target': '#b13'}]},
#     {'text': 'For this analysis, we intend to adopt the OpenAIRE Research Graph1 [15] as our dataset of reference (hereafter, the Graph). The Graph is one of the core services provided by OpenAIRE AMKE2 , a not-for-profit legal entity operating an infrastructure that offers global services in support of Open Science scholarly workflows. The Graph aggregates metadata from 96,514 scholarly sources (as of October 2021), comprising literature, research data and software repositories, publishers, and scholarly registries, such as ORCID, ROR, re3data, OpenDOAR, Crossref, and DataCite. It thus provides a longitudinal view of the global science record by delivering an extensive collection of heterogeneous research products interconnected with the relevant semantic relations. The semantic relations conducive to this study adhere to the specification drawn in the DataCite Schema documentation 3 and are both collected from DataCite4 , EMBL-EBI, and Crossref Event Data, as well as derived from the inference full-text algorithms embedded in the OpenAIRE Graph provision workflow, and the feedback from OpenAIRE portals users.',
#      'refs': [{'start': 65, 'end': 66, 'marker': None, 'target': '#foot_0'},
#       {'start': 67, 'end': 71, 'marker': 'bibr', 'target': '#b14'},
#       {'start': 187, 'end': 188, 'marker': None, 'target': '#foot_1'},
#       {'start': 882, 'end': 883, 'marker': None, 'target': '#foot_2'},
#       {'start': 920, 'end': 921, 'marker': None, 'target': '#foot_3'}]}]},
#   {'title': 'Methods',
#    'paragraphs': [{'text': 'First and foremost, a strategy to select the relevant literature and research data and software records needs to be devised. To this end, let 𝑝 be a publication and 𝑑 a research data (or a software) contextually produced within the same research effort (e.g., 𝑝 describes a research effort to conduct a measuring campaign eventually producing the dataset 𝑑 released contextually to the publication). In principle, it is possible to select all the 𝑝 ↔ 𝑑 couples by looking at the semantics of the relations linking literature records to non-literature records within the OpenAIRE Research Graph. In our case, we plan to use the semantic IsSupplementTo (and inverse IsSupplementedBy), which is the DataCite relation type indicating that a dataset 𝑑 is supplementary material for a publication 𝑝.',
#      'refs': []},
#     {'text': 'Once the relevant 𝑝 ↔ 𝑑 couples have been selected, we need to proceed with the analysis of the author sets and their interpretation. Let 𝐴 𝑝 be the set of authors of a publication 𝑝, and 𝐴 𝑑 the set of authors of a connected research data (or software) 𝑑, the scope of the analysis will be threefold. Firstly, the cardinality of the two sets |𝐴 𝑝 | and |𝐴 𝑑 | can be compared to understand whether there is any difference in the workforce when moving from literature items to relevant research data. Secondly, the composition of the two author sets will be considered in order to analyse the intersection 𝐴 𝑝 ∩𝐴 𝑑 and the symmetric difference 𝐴 𝑝 ∆ 𝐴 𝑑 = (𝐴 𝑝 ∖𝐴 𝑑 )∪(𝐴 𝑑 ∖𝐴 𝑝 ). Lastly, the ordering of the two author sets will be inspected to understand whether there are significant changes in the ranks of the same authors across the two sets and, if this is the case, which are the more frequent patterns.',
#      'refs': []},
#     {'text': 'Indeed, if the quantity of the available data points supports it, such analysis can be put in time perspective to analyse whether and how the trend evolved throughout the years globally and across different disciplines.',
#      'refs': []}]},
#   {'title': 'Caveats',
#    'paragraphs': [{'text': 'This section analyses two identified major caveats and related challenges that we have to face in this analysis. The first one is related to the inherent uncertainty of semantic relations specified among literature and research data records, while the second is related to the long-standing challenge of author disambiguation. For each, we outline the strategy we intend to follow to solve, or at least mitigate, the side effects of the caveats here described.',
#      'refs': []}]},
#   {'title': 'Semantic relation uncertainty',
#    'paragraphs': [{'text': 'Given a 𝑝 ↔ 𝑑 couple, the semantic expressed by the relation is defined by the user (i.e., researcher, librarian, curator) taking care of the deposition process of the research product (e.g., on Zenodo). Hence, the semantic is prone to human errors as it might not be very straightforward, which is the most appropriate one. On Zenodo, for example, the choice is drawn from a dropdown menu with scarce or limited guidance on the rationale behind the choice.',
#      'refs': []},
#     {'text': 'In order to mitigate this aspect, we plan to run a heuristic over 𝑝 ↔ 𝑑 couples tied by "vanilla" relations (e.g., Cites, References) and infer the unintentionally lost relations indicating supplemented material. A viable strategy could consist in retrofitting as supplemented material relations all the Cites (and inverse IsCitedBy) and References (and inverse IsReferencedBy) relations when the author sets share at least an author and the year indicates that the two records are contextual (e.g., within six months apart).',
#      'refs': []},
#     {'text': 'A possible generalisation of the heuristic above would rely on multiple metadata fields such as the date of publication, the title and the author list itself to create a feature vector describing research outputs. Then the distance between such vectors representing publication records and non-literature records related with the proper semantic would allow us to define a confidence interval of similarity which characterises literature and related non-literature records. New supplement semantics can be inferred relying on such confidence interval: if the similarity between two feature vectors tied by "vanilla" relations lays within the interval, then the semantics has been probably misassigned, and thus it can be retrofitted as IsSupplementedBy (or IsSupplementTo, depending on the direction).',
#      'refs': []}]},
#   {'title': 'Author names disambiguation',
#    'paragraphs': [{'text': 'Author disambiguation is essential to make the set of authors 𝐴 𝑑 of the dataset (or software) 𝑑 and the set of authors 𝐴 𝑝 of the publication 𝑝 comparable.',
#      'refs': []},
#     {'text': 'The metadata definition of an author 𝑎 who contributed both in the publication 𝑝 and in the supplement dataset 𝑑, may not be the same in 𝑝 and 𝑑 respectively. In this case, if the intersection 𝐴 𝑝 ∩ 𝐴 𝑑 is computed, the author 𝑎 will not belong to the intersection because there are different definitions of 𝑎 in 𝐴 𝑝 and 𝐴 𝑑 . In this context, disambiguation is crucial to correctly detect that the author 𝑎 is the same in 𝐴 𝑝 and 𝐴 𝑑 despite multiple definitions.',
#      'refs': []},
#     {'text': 'Consider, for example, the publication with the DOI:https://doi.org/10.1186/s12865-015-0113-0 (Immune cell subsets and their gene expression profiles from human PBMC isolated by Vacutainer Cell Preparation Tube (CPT TM ) and standard density gradient). One of the datasets it is supplemented by is https://doi.org/10.6084/m9.figshare.c.3600443_d4.v1 (Additional file 4: Table S4 If the lists of authors are analysed, there are three authors which co-occur both in 𝐴 𝑝 and in 𝐴 𝑑 (Burgess, Christopher, Karwowska, Sylwia and Kroll, Werner). The three remaining authors differ in how their name is laid out: in 𝐴 𝑝 in fact the first names are followed by another initial (highlighted in boldface), while in 𝐴 𝑑 they do not; without finer author disambiguation strategies (e.g., plain string match) they would be considered different authors.',
#      'refs': [{'start': 376, 'end': 378, 'marker': 'table', 'target': None}]},
#     {'text': 'To address the author disambiguation problem, we can rely on the deduplication framework of OpenAIRE [16,17] and the distance metrics it provides to compute the distance between single authors and lists. It is worth noting that, in contrast to the standard deduplication task (i.e., establish the equivalence of alike research products), we are comparing lists of authors belonging to research outputs different in kind (i.e., literature with non-literature); these lists may not necessarily contain the same authors; hence, the methods provided for the deduplication need to be customised according to our needs.',
#      'refs': [{'start': 101, 'end': 105, 'marker': 'bibr', 'target': '#b15'},
#       {'start': 105, 'end': 108, 'marker': 'bibr', 'target': '#b16'}]}]}],
#  'tables': {},
#  'abstract': {'title': 'Abstract',
#   'paragraphs': [{'text': 'Authorship of scientific articles has profoundly changed from early science until now. If once upon a time a paper was authored by a handful of authors, scientific collaborations are much more prominent on average nowadays. As authorship (and citation) is essentially the primary reward mechanism according to the traditional research evaluation frameworks, it turned to be a rather hot-button topic from which a significant portion of academic disputes stems. However, the novel Open Science practices could be an opportunity to disrupt such dynamics and diversify the credit of the different scientific contributors involved in the diverse phases of the lifecycle of the same research effort. In fact, a paper and research data (or software) contextually published could exhibit different authorship to give credit to the various contributors right where it feels most appropriate. We argue that this can be computationally analysed by taking advantage of the wealth of information in model Open Science Graphs. Such a study can pave the way to understand better the dynamics and patterns of authorship in linked literature, research data and software, and how they evolved over the years.',
#     'refs': []}]}}

# %% [markdown]
# # Apply in batch

# %%
df = pd.read_pickle('../data/processed/papers.pkl')
df.head()
# Out:
#                          key  doi  \
# 0  conf/ircdl/AmbrosinoAPS23  NaN
# 1       conf/ircdl/BagchiD23  NaN
# 2  conf/ircdl/BaglioniMPBM23  NaN
# 3   conf/ircdl/BarbutiBRCP23  NaN
# 4       conf/ircdl/BardiBM23  NaN
#
#                                               url  \
# 0  https://dblp.org/rec/conf/ircdl/AmbrosinoAPS23
# 1       https://dblp.org/rec/conf/ircdl/BagchiD23
# 2  https://dblp.org/rec/conf/ircdl/BaglioniMPBM23
# 3   https://dblp.org/rec/conf/ircdl/BarbutiBRCP23
# 4       https://dblp.org/rec/conf/ircdl/BardiBM23
#
#                                          ee  year  \
# 0  https://ceur-ws.org/Vol-3365/short16.pdf  2023
# 1   https://ceur-ws.org/Vol-3365/short1.pdf  2023
# 2   https://ceur-ws.org/Vol-3365/paper2.pdf  2023
# 3  https://ceur-ws.org/Vol-3365/short17.pdf  2023
# 4  https://ceur-ws.org/Vol-3365/short12.pdf  2023
#
#                                              authors  \
# 0  [Maria Anna Ambrosino, Vanja Annunziata, Maria...
# 1                     [Mayukh Bagchi, Subhashis Das]
# 2  [Miriam Baglioni, Andrea Mannocci, Gina Pavone...
# 3  [Nicola Barbuti, Mauro De Bari, Stefania Riso,...
# 4      [Alessia Bardi, Margo Bargheer, Paolo Manghi]
#
#                                                title  venue    pages  length  \
# 0  The Hetor project: a joint effort to co-create...  IRCDL  216-224     8.0
# 1                   Disentangling Domain Ontologies.  IRCDL    17-28    11.0
# 2  (Semi)automated disambiguation of scholarly re...  IRCDL    47-59    12.0
# 3  The Open Memory Apulia Project. How Open Data ...  IRCDL  225-232     7.0
# 4  A Discovery Hub for Diamond Open Access publis...  IRCDL  162-166     4.0
#
#                              type access
# 0  Conference and Workshop Papers   open
# 1  Conference and Workshop Papers   open
# 2  Conference and Workshop Papers   open
# 3  Conference and Workshop Papers   open
# 4  Conference and Workshop Papers   open

# %%
for index, row in df[~df.ee.isna()].iterrows():
    pdf_path = '../data/raw/pdfs/' + row['key'].replace('/', '_') + '.pdf'
    json_path = '../data/processed/grobid/' + row['key'].replace('/', '_') + '.json'
    print(pdf_path)
    if os.path.exists(json_path):
        print('... done! skipping')
        continue
        
    article = grobid_parse(pdf_path)
    with open(json_path, 'w') as f:
        f.write(article.to_json())
        print('...done!')
# Out:
# ../data/raw/pdfs/conf_ircdl_AmbrosinoAPS23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BagchiD23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BaglioniMPBM23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiBRCP23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BardiBM23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BernasconiCM23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CastellanoSV23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CastellucciC23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DeglInnocentiCC23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FraisseBB23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GemelliVM23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LocaputoPC023.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MartogliaBRVSV23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MatviichukHP23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_McGillivrayCBPF23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MuzzupappaN23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Nunzio0GI0S23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PetrocelliF23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ruskov23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SicilianiSB23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SimeriT23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_StranisciPD23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroK23.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Allegrezza22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Antonelli22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ArrigoOZ22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiB22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiFC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BartalesiPL22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BernasconiCLSM22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CarraraMMC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CoradeschiDMSSS22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DaquinoPTV22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FanteFMQ22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliL22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FernandesAC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GhannadradACC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IrreraGS22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_JasmontsSS22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KatzGB22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KempfTC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KettunenKKPR22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Lana22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Lastilla22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MangioneCC22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MannocciIM22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MinutellaFMBM22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Muzzupappa22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PierroRF22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ScaboroPCS022.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TagarelliS22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroTMPD22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TartariGP22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_VichosBKCAMMV22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ZerhoudiGSS22.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AlmeidaFM21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AvanziCCG021.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BaglioniMMABB21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BernasconiBCCGL21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BernasconiCM21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BiasiniC0FMN21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DossoS21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FanteN21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ferilli21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ferrante0P21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GargiuloGTZ21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_HeilNH21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IrreraS21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LancioniMP0T21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MarinaiPRS21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SpadiSD21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Svarre21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ZanichelliETTC21.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_00010PS20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ArtiniCMG20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Barbuti20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BoccuzziCDFGLMM20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CastellanoV20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CerianiBM20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FabrisKS20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliR20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FontaninC20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FrancoAG20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Halaweh20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MarinaiCZGM20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MazzoliniPPV20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MenardiFMSSBT20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MessinaAF20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_RoccoS20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroC20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ZilioOT20.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiFS19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AmelioJTD19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AmmiratiFMMN19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BardiCM19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Beamer19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BellottoB19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BruzzoMM19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CarducciLRBPT19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CozzaHPN19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CresciMNTT19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DossoSS19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliA19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FontaninC19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GiannakopoulosF19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_HastCVA19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KarimovaC019.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Lana19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LatifBT19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LuziRP19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MetilliBMA19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MinelliSOBP19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PandolfoPZ19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PassonCST19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_RodriguesCS019.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SopranoM19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_VezzaniN19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_WittSDPFDCHUK19.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AdorniDKTV18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiNFM0OPS18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiNFS18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AllegrezzaM18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Balducci18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarberoT18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiCF18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BardiCM18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BasaldellaAST18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BasaldellaST18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BolelliBG18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Cerullo18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CorniaPBC18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Cuna18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliE18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliP18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_HastCV18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KhanRA18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LanaT18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MarlazziPSV18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MeghiniBMB18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SchiavoneMAB18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SeidenariBUFBB18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SixBL18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroC18.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiLMW17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ApollonioRBDCG17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AtzoriBMM17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BalducciB17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BaraldiGC17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Bolelli17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BrodicA17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CapobiancoM17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliERA17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FuriniMMM17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IorioNPPVC17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MeghiniBM17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroCRPN17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ZilioMO17.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiFS16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BartalesiM16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BraidesS16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BressanCVL16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CorbelliBBGC16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliCRE16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliER16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ferro16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ManghiABBA16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Micheletti16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_NartDPT16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Orio16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ponchia16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SavinoO16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Tammaro16.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Agosti15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BaraldiGC15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BazzanellaB15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CappellatoFFGJL15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ChuA15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CiottiDT15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ConsonniW15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DeglInnocentiCB15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliRE15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GarganoGCSZ15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IorioS15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Kettunen15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LavaroneOPS15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MannocciCMZ15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Meghini15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_NartDBAT15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TurchiMCO15.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiFOP14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AngeliniFLMSST14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Appleton14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiFRC14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BasileME14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BecchiBBFP14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BressanC14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BuccioNS14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Caffo14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CatarciIS14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CeciLM14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CoppiGC14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Cusimano14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DaquinoPTV14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliEG14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Giorgio14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_KobosBHMMS14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MinelliNOPSU14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_NartT14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PugliesePFR14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroC14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Thanos14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_X14.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiMOPS13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AloiaCMT13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ArtiniABBMMZ13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CatarciGST13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliEGB13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerraraT13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroMHC13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FumarolaPFMC13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IorioSGOB13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LeuzziFR13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MagarottoQV13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Manoni13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MartinoliE13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PeroniTVZ13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Raieli13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Sadeh13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Tammaro13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroCC13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ZengeneneCM13.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Agosti12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiBO12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AloiaCM12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AmatoBGR12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ArtiniBBDBMMSZ12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarberaMMT12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Barbuti12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BarbutiC12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Buzzetti12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CandelaCP12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CasarosaMG12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CeciLMMQ12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Erriquez12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerraraT12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS12a.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GuercioS12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_IorioSB12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MauroFE12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PalmiraniC12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PeroniTV12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Ponchia12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_RotellaFL12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_SugibuchiLS12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TammaroMC12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TarantoME12.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiABNDMPRT11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiANDPRT11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiFRSTT11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiO11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AloiaCM11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AloiaCM11a.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BasileEF11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BuccioDFMS11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CeciLFM11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CrivellariDNDF11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_EspositoFMBB11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_EspositoMTF11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliEBRV11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerraraPT11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerraraT11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LanciaPSST11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_LoglisciACME11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_ManfiolettiN11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MiottoO11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_TarantoME11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_YangSS11.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiBNMP10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BergaminM10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Caffo10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CanazzaD10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CanazzaO10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CandelaCT10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CastelliCMPTT10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_DAmicoBM10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliBBE10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliBMBE10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GentileZXI10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GranaBC10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Lunghi10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MagnaniM10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MarinaiMS10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MiottoMO10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_MustoNLGS10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_PudotaDBT10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Vitali10.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Agosti09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AgostiCNISTV09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AloiaCM09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_AmatoDPS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BacheC09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BaruzzoCDT09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BasileGLS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BolettieriFLMPRS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BuccioFMMO09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_BuccioMMMMOS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CandelaCMMP09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CandelaCP09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Casarosa09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_CatarciDGPPTT09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerilliBBE09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroP09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_FerroS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_GentileBS09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_JonesM09.pdf
# ... done! skipping
# ../data/raw/pdfs/conf_ircdl_Peters09.pdf
# ... done! skipping
